# %% [markdown]
# # Air Quality Index Analysis - a Descriptive and Inferential Analysis

# %% [markdown]
# ## I. Cleaning Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# reading the dataset
aqi_data = pd.read_csv("Dilshad_Garden_Data.csv")

# %%
aqi_data.head()
# Out:
#     Timestamp  PM2.5 (µg/m³)  PM10 (µg/m³)  NO (µg/m³)  NO2 (µg/m³)  \
# 0  2024-01-01         169.57        305.14       28.77        29.65
# 1  2024-01-02         148.21        288.49       29.95        27.63
# 2  2024-01-03         142.83        266.59       31.23        29.64
# 3  2024-01-04         183.10        343.50       37.54        33.01
# 4  2024-01-05         143.22        254.06       36.58        33.53
#
#    NOx (ppb)  NH3 (µg/m³)  SO2 (µg/m³)  CO (mg/m³)  Ozone (µg/m³)  ...  \
# 0      38.54        62.22        52.05        0.77          33.90  ...
# 1      38.40        59.98        29.71        0.78          32.73  ...
# 2      40.49        56.22        25.18        1.14          32.70  ...
# 3      47.30        56.74        21.95        0.88          36.09  ...
# 4      46.82        40.75        31.97        0.55          28.09  ...
#
#    MP-Xylene (µg/m³)  AT (°C)  RH (%)  WS (m/s)  WD (deg)  RF (mm)  \
# ...

# %%
aqi_data.tail()
# Out:
#       Timestamp  PM2.5 (µg/m³)  PM10 (µg/m³)  NO (µg/m³)  NO2 (µg/m³)  \
# 289  2024-10-16          78.06        184.02       31.52        28.99
# 290  2024-10-17         103.00        243.78       32.18        36.18
# 291  2024-10-18          90.13        229.82       47.11        48.01
# 292  2024-10-19          99.84        226.57       38.00        34.69
# 293  2024-10-20         100.20        217.90       34.25        36.10
#
#      NOx (ppb)  NH3 (µg/m³)  SO2 (µg/m³)  CO (mg/m³)  Ozone (µg/m³)  ...  \
# 289      39.91        23.69         4.64        2.67          24.77  ...
# 290      44.56        19.11         4.45        3.39          24.62  ...
# 291      61.52        38.29         4.32        2.68          25.35  ...
# 292      47.65        44.94         7.58        2.90          25.88  ...
# 293      45.60        48.06        10.06        2.38          25.92  ...
#
#      MP-Xylene (µg/m³)  AT (°C)  RH (%)  WS (m/s)  WD (deg)  RF (mm)  \
# ...

# %%
# removing null columns
